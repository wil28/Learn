# %% [markdown]
# <a href="https://colab.research.google.com/github/wil28/Wiliyanti/blob/master/Learning_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data visualization**

# %% [markdown]
# # Latihan 1

# %% [markdown]
# *1. Histogram*

# %%
# import pandas and matplotlib 
import pandas as pd 
import matplotlib.pyplot as plt 

# create 2D array of table given above 
data = [['E001', 'M', 34, 123, 'Normal', 350], 
		['E002', 'F', 40, 114, 'Overweight', 450], 
		['E003', 'F', 37, 135, 'Obesity', 169], 
		['E004', 'M', 30, 139, 'Underweight', 189], 
		['E005', 'F', 44, 117, 'Underweight', 183], 
		['E006', 'M', 36, 121, 'Normal', 80], 
		['E007', 'M', 32, 133, 'Obesity', 166], 
		['E008', 'F', 26, 140, 'Normal', 120], 
		['E009', 'M', 32, 133, 'Normal', 75], 
		['E010', 'M', 36, 133, 'Underweight', 40] ] 

# dataframe created with 
# the above data array 
df = pd.DataFrame(data, columns = ['EMPID', 'Gender', 
									'Age', 'Sales', 
									'BMI', 'Income'] ) 

# create histogram for numeric data 
df.hist() 

# show plot 
plt.show()

# %% [markdown]
# *2. Column Chart*

# %%
# Dataframe of previous code is used here 

# Plot the bar chart for numeric values 
# a comparison will be shown between 
# all 3 age, income, sales 
df.plot.bar() 
plt.show()
# plot between 2 attributes 
plt.bar(df['Age'], df['Sales']) 
plt.xlabel("Age") 
plt.ylabel("Sales") 
plt.show()

# %% [markdown]
# *3.Box plot chart*

# %%
# For each numeric attribute of dataframe 
df.plot.box()

# %%
# individual attribute box plot 
plt.boxplot(df['Income']) 
plt.show()

# %% [markdown]
# *4. Pie Chart*

# %%
plt.pie(df['Age'], labels = {"A", "B", "C", 
							"D", "E", "F", 
							"G", "H", "I", "J"}, 
							
autopct ='% 1.1f %%', shadow = True) 
plt.show() 

plt.pie(df['Income'], labels = {"A", "B", "C", 
								"D", "E", "F", 
								"G", "H", "I", "J"}, 
								
autopct ='% 1.1f %%', shadow = True) 
plt.show() 

plt.pie(df['Sales'], labels = {"A", "B", "C", 
							"D", "E", "F", 
							"G", "H", "I", "J"}, 
autopct ='% 1.1f %%', shadow = True) 
plt.show()

# %% [markdown]
# *5. Scatter plot*

# %%
# scatter plot between income and age 
plt.scatter(df['Income'], df['Age']) 
plt.show() 

# scatter plot between income and sales 
plt.scatter(df['Income'], df['Sales']) 
plt.show() 

# scatter plot between sales and age 
plt.scatter(df['Sales'], df['Age']) 
plt.show()

# %% [markdown]
# # Latihan 2 (Line Chart)

# %%
data = {
        'Jan' : [20,21,22,20],
        'Feb' : [23,24,25,24],
        'Mar' : [30,31,32,30],
        'Apr' : [33,32,33,34],
        'Jun' : [36,37,35,36],
        'Jul' : [37,38,36,36]}
tahun=['2000','2005','2010','2015']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
list(data.keys())
# Out:
# ['Jan', 'Feb', 'Mar', 'Apr', 'Jun', 'Jul']

# %%
bulan= list(data.keys())
print (bulan)
tahun
# Out:
# ['Jan', 'Feb', 'Mar', 'Apr', 'Jun', 'Jul']
# ['2000', '2005', '2010', '2015']

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure()
x_series = bulan
y_series_1=[]
rata=[]
for z in data.values():
  rata.append(sum(z)/len(tahun))
for x in data.values():
  y_series_1.append(x)
plt.plot(x_series,y_series_1)
plt.xlabel('Bulan')
plt.ylabel('Suhu')
plt.title('Grafik Suhu')
plt.legend(loc='upper left')
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# atau dengan data frame

# %%
df2 = pd.DataFrame.from_dict(data, orient='index', columns = ['2000', '2005', 
									'2010', '2015'] ) 
df2
# Out:
#      2000  2005  2010  2015
# Jan    20    21    22    20
# Feb    23    24    25    24
# Mar    30    31    32    30
# Apr    33    32    33    34
# Jun    36    37    35    36
# Jul    37    38    36    36

# %%
import matplotlib.path as mpath
# Line Chart
circle = mpath.Path.unit_circle()
df2.plot(marker=circle, markersize=5)
plt.title('Line Chart Berdasarkan Bulan')
plt.xlabel('Months')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# **Done!**
